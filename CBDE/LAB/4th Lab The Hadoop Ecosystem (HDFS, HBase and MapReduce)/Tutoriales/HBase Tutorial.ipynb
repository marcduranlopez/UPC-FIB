# %% [markdown]
# #CBDE Lab 4 (part 1) - The Hadoop ecosystem (Hadoop & HBase)
#
# #Tutorial

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Setup environment
#
# First, we will download and setup Hadoop and HBase. This notebook is configured to use the following versions of the systems:
# *   Java JDK 8
# *   Hadoop 3.3.6
# *   HBase 2.5.6
#
# In case some of the downloads fail (due to changes in versioning) the download link should be updated as well as all references to the version used.

# %% [markdown]
# ### Hadoop
#
# Download and install Hadoop

# %%
#Setup JVM 8 (JVM 11 might cause incompatibility issues)
# !apt-get update > /dev/null
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# Download the latest version of Hadoop
# !wget https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Unzip it
# the tar command with the -x flag to extract, -z to uncompress, -v for verbose output, and -f to specify that we are extracting from a file
# !tar -xzf hadoop-3.3.6.tar.gz
#copy hadoop file to user/local
# !mv hadoop-3.3.6/ /usr/local/
# Out:
# --2023-11-10 17:51:38--  https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 730107476 (696M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.6.tar.gz’
#
# hadoop-3.3.6.tar.gz 100%[===================>] 696.28M   180MB/s    in 3.9s
#
# 2023-11-10 17:51:42 (177 MB/s) - ‘hadoop-3.3.6.tar.gz’ saved [730107476/730107476]

# %% [markdown]
# Set environment variables

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop-3.3.6/"

# %%
# Add Hadoop BIN to PATH
current_path = os.getenv('PATH')
new_path = current_path+':/usr/local/hadoop-3.3.6/bin/'
os.environ["PATH"] = new_path

# %% [markdown]
# ### HBase
#
# Download and install HBase

# %%
# Get the latest HBase version
# !wget https://dlcdn.apache.org/hbase/2.5.6/hbase-2.5.6-bin.tar.gz
# !tar xzf hbase-2.5.6-bin.tar.gz
# Out:
# --2023-11-10 17:56:14--  https://dlcdn.apache.org/hbase/2.5.6/hbase-2.5.6-bin.tar.gz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 314596103 (300M) [application/x-gzip]
# Saving to: ‘hbase-2.5.6-bin.tar.gz’
#
# hbase-2.5.6-bin.tar 100%[===================>] 300.02M  21.0MB/s    in 5.4s
#
# 2023-11-10 17:56:30 (55.9 MB/s) - ‘hbase-2.5.6-bin.tar.gz’ saved [314596103/314596103]

# %% [markdown]
# Set environment variables

# %%
os.environ["HBASE_HOME"] = "/content/hbase-2.5.6/"
# !echo $HBASE_HOME
# Out:
# /content/hbase-2.5.6/

# %%
# Add HBase BIN to PATH
current_path = os.getenv('PATH')
new_path = current_path+':/content/hbase-2.5.6/bin'
os.environ["PATH"] = new_path
# !echo $PATH
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/usr/local/hadoop-3.3.6/bin/:/content/hbase-2.5.6/bin

# %% [markdown]
# Verify all variables are correctly set

# %%
# !echo $JAVA_HOME
# !echo $HADOOP_HOME
# !echo $HBASE_HOME
# Out:
# /usr/lib/jvm/java-8-openjdk-amd64
# /usr/local/hadoop-3.3.6/
# /content/hbase-2.5.6/

# %% [markdown]
# For the purpose of this lab we will use an HBase standalone instance, thus no further configuration is required. If you were to use it in a cluster mode you would need to update the *hbase_site.xml* file

# %%
# the file hbase-site.xml may need to be updated ...
#!cat $HBASE_HOME/conf/hbase-site.xml

# %% [markdown]
# ### Start HBase server

# %%
# !start-hbase.sh
# !jps
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]
# running master, logging to /content/hbase-2.5.6//logs/hbase--master-8e95860f6443.out
# 13812 Jps
# 13725 HMaster

# %% [markdown]
# # Bulk data loading
#
# First, we are going to interact with HBase through the HBase shell. We will download a sample CSV file and load it into an HBase table.
#
# See the following links for details on the available commands of the HBase shell:
#
# *   https://www.tutorialspoint.com/hbase/hbase_shell.htm
# *   https://www.guru99.com/hbase-shell-general-commands.html
#
# We will download a publicly available file from the open repository of CSV files at https://people.sc.fsu.edu/~jburkardt/data/csv/csv.html. Precisely, we will download the *airtravel.csv* dataset, which contains monthly transatlantic airtravel, in thousands of passengers, for 1958-1960. There are 4 fields, "Month", "1958", "1959" and "1960" and 12 records, "JAN" through "DEC". There is also an initial header line.

# %%
# Download sample file
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/airtravel.csv
# Out:
# --2023-11-10 18:21:06--  https://people.sc.fsu.edu/~jburkardt/data/csv/airtravel.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.0.22
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.0.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 321 [text/csv]
# Saving to: ‘airtravel.csv’
#
# airtravel.csv       100%[===================>]     321  --.-KB/s    in 0s
#
# 2023-11-10 18:21:07 (133 MB/s) - ‘airtravel.csv’ saved [321/321]

# %%
# Print its contents
# !cat airtravel.csv
# Out:
# "Month", "1958", "1959", "1960"
# "JAN",  340,  360,  417
# "FEB",  318,  342,  391
# "MAR",  362,  406,  419
# "APR",  348,  396,  461
# "MAY",  363,  420,  472
# "JUN",  435,  472,  535
# "JUL",  491,  548,  622
# "AUG",  505,  559,  606
# "SEP",  404,  463,  508
# "OCT",  359,  407,  461
# "NOV",  310,  362,  390
# "DEC",  337,  405,  432

# %% [markdown]
# Then, using the HBase shell we will try to drop the table if it already exists. In case it does not exist the command will raise an error. To drop a table in HBase it is required first to **disable** it and then **drop** it.

# %%
# !echo "disable 'airtravel'" | hbase shell -n
# !echo "drop 'airtravel'" | hbase shell -n

# %% [markdown]
# Then, we create the *airtravel* table. For demo purposes, we will define a single column family *years*, which will contain 3 qualifiers (one per year). The key of the table will be the month.

# %%
# !echo "create 'airtravel','years'" | hbase shell -n
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]
# 2023-11-10 18:16:05,031 INFO  [main] Configuration.deprecation (Configuration.java:logDeprecation(1294)) - hbase.client.pause.cqtbe is deprecated. Instead, use hbase.client.pause.server.overloaded
# 2023-11-10 18:16:05,173 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:zookeeper.version=3.5.7-f0fdd52973d373ffd9c86b81d99842dc2c7f660e, built on 02/10/2020 11:30 GMT
# 2023-11-10 18:16:05,174 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:host.name=8e95860f6443
# 2023-11-10 18:16:05,174 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.version=1.8.0_382
# 2023-11-10 18:16:05,174 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.vendor=Private Build
# 2023-11-10 18:16:05,174 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.home=/usr/lib/jvm/java-8-openjdk-amd64/jre
# 2023-11-10 18:16:05,174 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.class.path=/content/hbase-2.5.6//lib/ruby/jruby-complete-9.2.13.0.jar:/content/hbase-2.5.6//conf:/usr/lib/jvm/java-8-openjdk-amd64/lib/tools.jar:/content/hbase-2.5.6/:/content/hbase-2.5.6//lib/agrona-1.12.0.jar:/content/hbase-2.5.6//lib/aircompressor-0.24.jar:/content/hbase-2.5.6//lib/aopalliance-1.0.jar:/content/hbase-2.5.6//lib/apacheds-i18n-2.0.0-M15.jar:/content/hbase-2.5.6//lib/apacheds-kerberos-codec-2.0.0-M15.jar:/content/hbase-2.5.6//lib/api-asn1-api-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-i18n-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-util-1.0.0-M20.jar:/content/hbase-2.5.6//lib/asm-3.1.jar:/content/hbase-2.5.6//lib/avro-1.11.3.jar:/content/hbase-2.5.6//lib/brotli4j-1.11.0.jar:/content/hbase-2.5.6//lib/byte-buddy-1.9.10.jar:/content/hbase-2.5.6//lib/byte-buddy-agent-1.9.10.jar:/content/hbase-2.5.6//lib/caffeine-2.8.1.jar:/content/hbase-2.5.6//lib/checker-qual-3.1.0.jar:/content/hbase-2.5.6//lib/commons-cli-1.2.jar:/content/hbase-2.5.6//lib/commons-codec-1.15.jar:/content/hbase-2.5.6//lib/commons-collections-3.2.2.jar:/content/hbase-2.5.6//lib/commons-compress-1.21.jar:/content/hbase-2.5.6//lib/commons-configuration-1.6.jar:/content/hbase-2.5.6//lib/commons-crypto-1.1.0.jar:/content/hbase-2.5.6//lib/commons-csv-1.0.jar:/content/hbase-2.5.6//lib/commons-daemon-1.0.13.jar:/content/hbase-2.5.6//lib/commons-digester-1.8.jar:/content/hbase-2.5.6//lib/commons-io-2.11.0.jar:/content/hbase-2.5.6//lib/commons-lang-2.6.jar:/content/hbase-2.5.6//lib/commons-lang3-3.9.jar:/content/hbase-2.5.6//lib/commons-math3-3.6.1.jar:/content/hbase-2.5.6//lib/commons-net-3.1.jar:/content/hbase-2.5.6//lib/curator-client-4.2.0.jar:/content/hbase-2.5.6//lib/curator-framework-4.2.0.jar:/content/hbase-2.5.6//lib/curator-recipes-4.2.0.jar:/content/hbase-2.5.6//lib/disruptor-3.4.2.jar:/content/hbase-2.5.6//lib/ehcache-3.3.1.jar:/content/hbase-2.5.6//lib/error_prone_annotations-2.21.1.jar:/content/hbase-2.5.6//lib/fst-2.50.jar:/content/hbase-2.5.6//lib/geronimo-jcache_1.0_spec-1.0-alpha-1.jar:/content/hbase-2.5.6//lib/gson-2.2.4.jar:/content/hbase-2.5.6//lib/guava-11.0.2.jar:/content/hbase-2.5.6//lib/guice-3.0.jar:/content/hbase-2.5.6//lib/guice-servlet-3.0.jar:/content/hbase-2.5.6//lib/hadoop-annotations-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-auth-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-distcp-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-app-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-core-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-hs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-jobclient-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-shuffle-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-minicluster-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-api-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-registry-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-applicationhistoryservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-nodemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-resourcemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-tests-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-timelineservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-web-proxy-2.10.2.jar:/content/hbase-2.5.6//lib/hamcrest-core-1.3.jar:/content/hbase-2.5.6//lib/hb ...
# 2023-11-10 18:16:05,363 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.library.path=/usr/local/hadoop-3.3.6//lib/native
# 2023-11-10 18:16:05,363 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.io.tmpdir=/tmp
# 2023-11-10 18:16:05,363 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.compiler=<NA>
# 2023-11-10 18:16:05,363 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.name=Linux
# 2023-11-10 18:16:05,363 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.arch=amd64
# 2023-11-10 18:16:05,364 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.version=5.15.120+
# 2023-11-10 18:16:05,364 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.name=root
# 2023-11-10 18:16:05,364 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.home=/root
# 2023-11-10 18:16:05,364 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.dir=/content
# 2023-11-10 18:16:05,364 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.free=99MB
# 2023-11-10 18:16:05,364 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.max=3229MB
# 2023-11-10 18:16:05,364 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.total=197MB
# 2023-11-10 18:16:05,377 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (ZooKeeper.java:<init>(868)) - Initiating client connection, connectString=127.0.0.1:2181 sessionTimeout=90000 watcher=org.apache.hadoop.hbase.zookeeper.ReadOnlyZKClient$$Lambda$227/811140598@1267e458
# 2023-11-10 18:16:05,389 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] common.X509Util (X509Util.java:<clinit>(79)) - Setting -D jdk.tls.rejectClientInitiatedRenegotiation=true to disable client-initiated TLS renegotiation
# 2023-11-10 18:16:05,400 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ClientCnxnSocket (ClientCnxnSocket.java:initProperties(237)) - jute.maxbuffer value is 4194304 Bytes
# 2023-11-10 18:16:05,415 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ClientCnxn (ClientCnxn.java:initRequestTimeout(1653)) - zookeeper.request.timeout value is 0. feature enabled=
# 2023-11-10 18:16:05,442 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:logStartConnect(1112)) - Opening socket connection to server localhost/127.0.0.1:2181. Will not attempt to authenticate using SASL (unknown error)
# 2023-11-10 18:16:05,460 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:primeConnection(959)) - Socket connection established, initiating session, client: /127.0.0.1:34524, server: localhost/127.0.0.1:2181
# 2023-11-10 18:16:05,478 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:onConnected(1394)) - Session establishment complete on server localhost/127.0.0.1:2181, sessionid = 0x100002cc3cc0004, negotiated timeout = 40000
# hbase:001:0> create 'airtravel','years'
# 2023-11-10 18:16:16,576 INFO  [main] client.HBaseAdmin (HBaseAdmin.java:postOperationResult(3591)) - Operation: CREATE, Table Name: default:airtravel, procId: 9 completed
# Created table airtravel
# Took 1.4765 seconds
# => Hbase::Table - airtravel
# hbase:002:0>

# %% [markdown]
# Using the **list** command we show the list of tables created in HBase.

# %%
# !echo "list" | hbase shell -n
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]
# 2023-11-10 18:16:51,123 INFO  [main] Configuration.deprecation (Configuration.java:logDeprecation(1294)) - hbase.client.pause.cqtbe is deprecated. Instead, use hbase.client.pause.server.overloaded
# 2023-11-10 18:16:51,204 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:zookeeper.version=3.5.7-f0fdd52973d373ffd9c86b81d99842dc2c7f660e, built on 02/10/2020 11:30 GMT
# 2023-11-10 18:16:51,204 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:host.name=8e95860f6443
# 2023-11-10 18:16:51,204 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.version=1.8.0_382
# 2023-11-10 18:16:51,204 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.vendor=Private Build
# 2023-11-10 18:16:51,205 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.home=/usr/lib/jvm/java-8-openjdk-amd64/jre
# 2023-11-10 18:16:51,205 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.class.path=/content/hbase-2.5.6//lib/ruby/jruby-complete-9.2.13.0.jar:/content/hbase-2.5.6//conf:/usr/lib/jvm/java-8-openjdk-amd64/lib/tools.jar:/content/hbase-2.5.6/:/content/hbase-2.5.6//lib/agrona-1.12.0.jar:/content/hbase-2.5.6//lib/aircompressor-0.24.jar:/content/hbase-2.5.6//lib/aopalliance-1.0.jar:/content/hbase-2.5.6//lib/apacheds-i18n-2.0.0-M15.jar:/content/hbase-2.5.6//lib/apacheds-kerberos-codec-2.0.0-M15.jar:/content/hbase-2.5.6//lib/api-asn1-api-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-i18n-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-util-1.0.0-M20.jar:/content/hbase-2.5.6//lib/asm-3.1.jar:/content/hbase-2.5.6//lib/avro-1.11.3.jar:/content/hbase-2.5.6//lib/brotli4j-1.11.0.jar:/content/hbase-2.5.6//lib/byte-buddy-1.9.10.jar:/content/hbase-2.5.6//lib/byte-buddy-agent-1.9.10.jar:/content/hbase-2.5.6//lib/caffeine-2.8.1.jar:/content/hbase-2.5.6//lib/checker-qual-3.1.0.jar:/content/hbase-2.5.6//lib/commons-cli-1.2.jar:/content/hbase-2.5.6//lib/commons-codec-1.15.jar:/content/hbase-2.5.6//lib/commons-collections-3.2.2.jar:/content/hbase-2.5.6//lib/commons-compress-1.21.jar:/content/hbase-2.5.6//lib/commons-configuration-1.6.jar:/content/hbase-2.5.6//lib/commons-crypto-1.1.0.jar:/content/hbase-2.5.6//lib/commons-csv-1.0.jar:/content/hbase-2.5.6//lib/commons-daemon-1.0.13.jar:/content/hbase-2.5.6//lib/commons-digester-1.8.jar:/content/hbase-2.5.6//lib/commons-io-2.11.0.jar:/content/hbase-2.5.6//lib/commons-lang-2.6.jar:/content/hbase-2.5.6//lib/commons-lang3-3.9.jar:/content/hbase-2.5.6//lib/commons-math3-3.6.1.jar:/content/hbase-2.5.6//lib/commons-net-3.1.jar:/content/hbase-2.5.6//lib/curator-client-4.2.0.jar:/content/hbase-2.5.6//lib/curator-framework-4.2.0.jar:/content/hbase-2.5.6//lib/curator-recipes-4.2.0.jar:/content/hbase-2.5.6//lib/disruptor-3.4.2.jar:/content/hbase-2.5.6//lib/ehcache-3.3.1.jar:/content/hbase-2.5.6//lib/error_prone_annotations-2.21.1.jar:/content/hbase-2.5.6//lib/fst-2.50.jar:/content/hbase-2.5.6//lib/geronimo-jcache_1.0_spec-1.0-alpha-1.jar:/content/hbase-2.5.6//lib/gson-2.2.4.jar:/content/hbase-2.5.6//lib/guava-11.0.2.jar:/content/hbase-2.5.6//lib/guice-3.0.jar:/content/hbase-2.5.6//lib/guice-servlet-3.0.jar:/content/hbase-2.5.6//lib/hadoop-annotations-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-auth-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-distcp-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-app-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-core-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-hs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-jobclient-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-shuffle-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-minicluster-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-api-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-registry-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-applicationhistoryservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-nodemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-resourcemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-tests-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-timelineservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-web-proxy-2.10.2.jar:/content/hbase-2.5.6//lib/hamcrest-core-1.3.jar:/content/hbase-2.5.6//lib/hb ...
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.library.path=/usr/local/hadoop-3.3.6//lib/native
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.io.tmpdir=/tmp
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.compiler=<NA>
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.name=Linux
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.arch=amd64
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.version=5.15.120+
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.name=root
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.home=/root
# 2023-11-10 18:16:51,300 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.dir=/content
# 2023-11-10 18:16:51,301 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.free=98MB
# 2023-11-10 18:16:51,301 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.max=3229MB
# 2023-11-10 18:16:51,301 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.total=197MB
# 2023-11-10 18:16:51,310 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (ZooKeeper.java:<init>(868)) - Initiating client connection, connectString=127.0.0.1:2181 sessionTimeout=90000 watcher=org.apache.hadoop.hbase.zookeeper.ReadOnlyZKClient$$Lambda$227/2033637021@64371270
# 2023-11-10 18:16:51,320 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] common.X509Util (X509Util.java:<clinit>(79)) - Setting -D jdk.tls.rejectClientInitiatedRenegotiation=true to disable client-initiated TLS renegotiation
# 2023-11-10 18:16:51,329 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ClientCnxnSocket (ClientCnxnSocket.java:initProperties(237)) - jute.maxbuffer value is 4194304 Bytes
# 2023-11-10 18:16:51,343 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ClientCnxn (ClientCnxn.java:initRequestTimeout(1653)) - zookeeper.request.timeout value is 0. feature enabled=
# 2023-11-10 18:16:51,399 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:logStartConnect(1112)) - Opening socket connection to server localhost/127.0.0.1:2181. Will not attempt to authenticate using SASL (unknown error)
# 2023-11-10 18:16:51,407 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:primeConnection(959)) - Socket connection established, initiating session, client: /127.0.0.1:41694, server: localhost/127.0.0.1:2181
# 2023-11-10 18:16:51,424 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:onConnected(1394)) - Session establishment complete on server localhost/127.0.0.1:2181, sessionid = 0x100002cc3cc0005, negotiated timeout = 40000
# hbase:001:0> list
# TABLE
# airtravel
# 1 row(s)
# Took 1.1818 seconds
# => ["airtravel"]
# hbase:002:0>

# %% [markdown]
# Next, to load the data in HBase we first need to move the CSV file from the local filesystem to the Hadoop filesystem. For that, we will use the **copyFromLocal** option of the **dfs** command. But first, using the **sed** command we willl remove the header of the CSV file (i.e., the first line).

# %%
# !sed -i '1d' airtravel.csv
# !hdfs dfs -copyFromLocal airtravel.csv /tmp

# %% [markdown]
# Then, we will use the **ImportTsv** package (which is already provided by HBase) to bulk load a CSV file into an HBase table.

# %%
# !hbase org.apache.hadoop.hbase.mapreduce.ImportTsv -Dimporttsv.separator=',' -Dimporttsv.columns="HBASE_ROW_KEY,years:1958,years:1959,years:1960" airtravel /tmp/airtravel.csv
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]
# 2023-11-10 18:24:12,926 INFO  [main] Configuration.deprecation (Configuration.java:logDeprecation(1294)) - hbase.client.pause.cqtbe is deprecated. Instead, use hbase.client.pause.server.overloaded
# 2023-11-10 18:24:13,114 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:zookeeper.version=3.5.7-f0fdd52973d373ffd9c86b81d99842dc2c7f660e, built on 02/10/2020 11:30 GMT
# 2023-11-10 18:24:13,114 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:host.name=8e95860f6443
# 2023-11-10 18:24:13,114 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.version=1.8.0_382
# 2023-11-10 18:24:13,115 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.vendor=Private Build
# 2023-11-10 18:24:13,115 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.home=/usr/lib/jvm/java-8-openjdk-amd64/jre
# 2023-11-10 18:24:13,116 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.class.path=/content/hbase-2.5.6//conf:/usr/lib/jvm/java-8-openjdk-amd64/lib/tools.jar:/content/hbase-2.5.6/:/content/hbase-2.5.6//lib/agrona-1.12.0.jar:/content/hbase-2.5.6//lib/aircompressor-0.24.jar:/content/hbase-2.5.6//lib/aopalliance-1.0.jar:/content/hbase-2.5.6//lib/apacheds-i18n-2.0.0-M15.jar:/content/hbase-2.5.6//lib/apacheds-kerberos-codec-2.0.0-M15.jar:/content/hbase-2.5.6//lib/api-asn1-api-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-i18n-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-util-1.0.0-M20.jar:/content/hbase-2.5.6//lib/asm-3.1.jar:/content/hbase-2.5.6//lib/avro-1.11.3.jar:/content/hbase-2.5.6//lib/brotli4j-1.11.0.jar:/content/hbase-2.5.6//lib/byte-buddy-1.9.10.jar:/content/hbase-2.5.6//lib/byte-buddy-agent-1.9.10.jar:/content/hbase-2.5.6//lib/caffeine-2.8.1.jar:/content/hbase-2.5.6//lib/checker-qual-3.1.0.jar:/content/hbase-2.5.6//lib/commons-cli-1.2.jar:/content/hbase-2.5.6//lib/commons-codec-1.15.jar:/content/hbase-2.5.6//lib/commons-collections-3.2.2.jar:/content/hbase-2.5.6//lib/commons-compress-1.21.jar:/content/hbase-2.5.6//lib/commons-configuration-1.6.jar:/content/hbase-2.5.6//lib/commons-crypto-1.1.0.jar:/content/hbase-2.5.6//lib/commons-csv-1.0.jar:/content/hbase-2.5.6//lib/commons-daemon-1.0.13.jar:/content/hbase-2.5.6//lib/commons-digester-1.8.jar:/content/hbase-2.5.6//lib/commons-io-2.11.0.jar:/content/hbase-2.5.6//lib/commons-lang-2.6.jar:/content/hbase-2.5.6//lib/commons-lang3-3.9.jar:/content/hbase-2.5.6//lib/commons-math3-3.6.1.jar:/content/hbase-2.5.6//lib/commons-net-3.1.jar:/content/hbase-2.5.6//lib/curator-client-4.2.0.jar:/content/hbase-2.5.6//lib/curator-framework-4.2.0.jar:/content/hbase-2.5.6//lib/curator-recipes-4.2.0.jar:/content/hbase-2.5.6//lib/disruptor-3.4.2.jar:/content/hbase-2.5.6//lib/ehcache-3.3.1.jar:/content/hbase-2.5.6//lib/error_prone_annotations-2.21.1.jar:/content/hbase-2.5.6//lib/fst-2.50.jar:/content/hbase-2.5.6//lib/geronimo-jcache_1.0_spec-1.0-alpha-1.jar:/content/hbase-2.5.6//lib/gson-2.2.4.jar:/content/hbase-2.5.6//lib/guava-11.0.2.jar:/content/hbase-2.5.6//lib/guice-3.0.jar:/content/hbase-2.5.6//lib/guice-servlet-3.0.jar:/content/hbase-2.5.6//lib/hadoop-annotations-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-auth-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-distcp-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-app-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-core-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-hs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-jobclient-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-shuffle-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-minicluster-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-api-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-registry-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-applicationhistoryservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-nodemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-resourcemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-tests-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-timelineservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-web-proxy-2.10.2.jar:/content/hbase-2.5.6//lib/hamcrest-core-1.3.jar:/content/hbase-2.5.6//lib/hbase-annotations-2.5.6.jar:/content/hbase-2.5.6//lib/hbase-a ...
# 2023-11-10 18:24:13,264 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.library.path=/usr/local/hadoop-3.3.6//lib/native
# 2023-11-10 18:24:13,264 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.io.tmpdir=/tmp
# 2023-11-10 18:24:13,265 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.compiler=<NA>
# 2023-11-10 18:24:13,265 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.name=Linux
# 2023-11-10 18:24:13,265 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.arch=amd64
# 2023-11-10 18:24:13,265 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.version=5.15.120+
# 2023-11-10 18:24:13,265 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.name=root
# 2023-11-10 18:24:13,266 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.home=/root
# 2023-11-10 18:24:13,266 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.dir=/content
# 2023-11-10 18:24:13,266 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.free=165MB
# 2023-11-10 18:24:13,266 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.max=3229MB
# 2023-11-10 18:24:13,266 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.total=197MB
# 2023-11-10 18:24:13,273 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (ZooKeeper.java:<init>(868)) - Initiating client connection, connectString=127.0.0.1:2181 sessionTimeout=90000 watcher=org.apache.hadoop.hbase.zookeeper.ReadOnlyZKClient$$Lambda$19/1766882207@7d70556a
# 2023-11-10 18:24:13,286 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] common.X509Util (X509Util.java:<clinit>(79)) - Setting -D jdk.tls.rejectClientInitiatedRenegotiation=true to disable client-initiated TLS renegotiation
# 2023-11-10 18:24:13,304 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ClientCnxnSocket (ClientCnxnSocket.java:initProperties(237)) - jute.maxbuffer value is 4194304 Bytes
# 2023-11-10 18:24:13,330 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ClientCnxn (ClientCnxn.java:initRequestTimeout(1653)) - zookeeper.request.timeout value is 0. feature enabled=
# 2023-11-10 18:24:13,359 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:logStartConnect(1112)) - Opening socket connection to server localhost/127.0.0.1:2181. Will not attempt to authenticate using SASL (unknown error)
# 2023-11-10 18:24:13,366 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:primeConnection(959)) - Socket connection established, initiating session, client: /127.0.0.1:42828, server: localhost/127.0.0.1:2181
# 2023-11-10 18:24:13,377 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:onConnected(1394)) - Session establishment complete on server localhost/127.0.0.1:2181, sessionid = 0x100002cc3cc0006, negotiated timeout = 40000
# 2023-11-10 18:24:17,534 INFO  [main] client.ConnectionImplementation (ConnectionImplementation.java:closeMasterService(2039)) - Closing master protocol: MasterService
# 2023-11-10 18:24:17,561 INFO  [main] Configuration.deprecation (Configuration.java:logDeprecation(1294)) - session.id is deprecated. Instead, use dfs.metrics.session-id
# 2023-11-10 18:24:17,563 INFO  [main] jvm.JvmMetrics (JvmMetrics.java:init(79)) - Initializing JVM Metrics with processName=JobTracker, sessionId=
# 2023-11-10 18:24:17,609 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b] zookeeper.ZooKeeper (ZooKeeper.java:<init>(868)) - Initiating client connection, connectString=127.0.0.1:2181 sessionTimeout=90000 watcher=org.apache.hadoop.hbase.zookeeper.ReadOnlyZKClient$$Lambda$19/1766882207@7d70556a
# 2023-11-10 18:24:17,610 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b] zookeeper.ClientCnxnSocket (ClientCnxnSocket.java:initProperties(237)) - jute.maxbuffer value is 4194304 Bytes
# 2023-11-10 18:24:17,611 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b] zookeeper.ClientCnxn (ClientCnxn.java:initRequestTimeout(1653)) - zookeeper.request.timeout value is 0. feature enabled=
# 2023-11-10 18:24:17,617 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:logStartConnect(1112)) - Opening socket connection to server localhost/127.0.0.1:2181. Will not attempt to authenticate using SASL (unknown error)
# 2023-11-10 18:24:17,619 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:primeConnection(959)) - Socket connection established, initiating session, client: /127.0.0.1:42842, server: localhost/127.0.0.1:2181
# 2023-11-10 18:24:17,622 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:onConnected(1394)) - Session establishment complete on server localhost/127.0.0.1:2181, sessionid = 0x100002cc3cc0007, negotiated timeout = 40000
# 2023-11-10 18:24:17,644 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae] zookeeper.ZooKeeper (ZooKeeper.java:close(1422)) - Session: 0x100002cc3cc0006 closed
# 2023-11-10 18:24:17,645 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0247d8ae-EventThread] zookeeper.ClientCnxn (ClientCnxn.java:run(524)) - EventThread shut down for session: 0x100002cc3cc0006
# 2023-11-10 18:24:17,769 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b] zookeeper.ZooKeeper (ZooKeeper.java:close(1422)) - Session: 0x100002cc3cc0007 closed
# 2023-11-10 18:24:17,769 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x4a3e3e8b-EventThread] zookeeper.ClientCnxn (ClientCnxn.java:run(524)) - EventThread shut down for session: 0x100002cc3cc0007
# 2023-11-10 18:24:17,877 INFO  [main] input.FileInputFormat (FileInputFormat.java:listStatus(289)) - Total input files to process : 1
# 2023-11-10 18:24:17,908 INFO  [main] mapreduce.JobSubmitter (JobSubmitter.java:submitJobInternal(204)) - number of splits:1
# 2023-11-10 18:24:18,190 INFO  [main] mapreduce.JobSubmitter (JobSubmitter.java:printTokens(300)) - Submitting tokens for job: job_local361175272_0001
# 2023-11-10 18:24:18,489 INFO  [main] mapred.LocalDistributedCacheManager (LocalDistributedCacheManager.java:symlink(200)) - Creating symlink: /tmp/hadoop-root/mapred/local/1699640658303/libjars <- /content/libjars/*
# 2023-11-10 18:24:18,497 WARN  [main] fs.FileUtil (FileUtil.java:symLink(888)) - Command 'ln -s /tmp/hadoop-root/mapred/local/1699640658303/libjars /content/libjars/*' failed 1 with: ln: failed to create symbolic link '/content/libjars/*': No such file or directory
#
# 2023-11-10 18:24:18,498 WARN  [main] mapred.LocalDistributedCacheManager (LocalDistributedCacheManager.java:symlink(202)) - Failed to create symlink: /tmp/hadoop-root/mapred/local/1699640658303/libjars <- /content/libjars/*
# 2023-11-10 18:24:18,498 INFO  [main] mapred.LocalDistributedCacheManager (LocalDistributedCacheManager.java:setup(164)) - Localized file:/tmp/hadoop-root/mapred/staging/root361175272/.staging/job_local361175272_0001/libjars as file:/tmp/hadoop-root/mapred/local/1699640658303/libjars
# 2023-11-10 18:24:18,609 INFO  [main] mapreduce.Job (Job.java:submit(1577)) - The url to track the job: http://localhost:8080/
# 2023-11-10 18:24:18,610 INFO  [main] mapreduce.Job (Job.java:monitorAndPrintJob(1622)) - Running job: job_local361175272_0001
# 2023-11-10 18:24:18,617 INFO  [Thread-7] mapred.LocalJobRunner (LocalJobRunner.java:createOutputCommitter(500)) - OutputCommitter set in config null
# 2023-11-10 18:24:18,653 INFO  [Thread-7] mapred.LocalJobRunner (LocalJobRunner.java:createOutputCommitter(518)) - OutputCommitter is org.apache.hadoop.hbase.mapreduce.TableOutputCommitter
# 2023-11-10 18:24:18,693 INFO  [Thread-7] mapred.LocalJobRunner (LocalJobRunner.java:runTasks(477)) - Waiting for map tasks
# 2023-11-10 18:24:18,694 INFO  [LocalJobRunner Map Task Executor #0] mapred.LocalJobRunner (LocalJobRunner.java:run(251)) - Starting task: attempt_local361175272_0001_m_000000_0
# 2023-11-10 18:24:18,793 INFO  [LocalJobRunner Map Task Executor #0] mapred.Task (Task.java:initialize(620)) -  Using ResourceCalculatorProcessTree : [ ]
# 2023-11-10 18:24:18,808 INFO  [LocalJobRunner Map Task Executor #0] mapred.MapTask (MapTask.java:runNewMapper(763)) - Processing split: file:/tmp/airtravel.csv:0+289
# 2023-11-10 18:24:18,829 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4] zookeeper.ZooKeeper (ZooKeeper.java:<init>(868)) - Initiating client connection, connectString=127.0.0.1:2181 sessionTimeout=90000 watcher=org.apache.hadoop.hbase.zookeeper.ReadOnlyZKClient$$Lambda$19/1766882207@7d70556a
# 2023-11-10 18:24:18,829 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4] zookeeper.ClientCnxnSocket (ClientCnxnSocket.java:initProperties(237)) - jute.maxbuffer value is 4194304 Bytes
# 2023-11-10 18:24:18,830 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4] zookeeper.ClientCnxn (ClientCnxn.java:initRequestTimeout(1653)) - zookeeper.request.timeout value is 0. feature enabled=
# 2023-11-10 18:24:18,832 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:logStartConnect(1112)) - Opening socket connection to server localhost/127.0.0.1:2181. Will not attempt to authenticate using SASL (unknown error)
# 2023-11-10 18:24:18,832 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:primeConnection(959)) - Socket connection established, initiating session, client: /127.0.0.1:42852, server: localhost/127.0.0.1:2181
# 2023-11-10 18:24:18,836 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:onConnected(1394)) - Session establishment complete on server localhost/127.0.0.1:2181, sessionid = 0x100002cc3cc0008, negotiated timeout = 40000
# 2023-11-10 18:24:18,845 INFO  [LocalJobRunner Map Task Executor #0] mapreduce.TableOutputFormat (TableOutputFormat.java:<init>(100)) - Created table instance for airtravel
# 2023-11-10 18:24:18,869 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2] zookeeper.ZooKeeper (ZooKeeper.java:<init>(868)) - Initiating client connection, connectString=127.0.0.1:2181 sessionTimeout=90000 watcher=org.apache.hadoop.hbase.zookeeper.ReadOnlyZKClient$$Lambda$19/1766882207@7d70556a
# 2023-11-10 18:24:18,869 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2] zookeeper.ClientCnxnSocket (ClientCnxnSocket.java:initProperties(237)) - jute.maxbuffer value is 4194304 Bytes
# 2023-11-10 18:24:18,870 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2] zookeeper.ClientCnxn (ClientCnxn.java:initRequestTimeout(1653)) - zookeeper.request.timeout value is 0. feature enabled=
# 2023-11-10 18:24:18,875 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:logStartConnect(1112)) - Opening socket connection to server localhost/127.0.0.1:2181. Will not attempt to authenticate using SASL (unknown error)
# 2023-11-10 18:24:18,876 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:primeConnection(959)) - Socket connection established, initiating session, client: /127.0.0.1:42858, server: localhost/127.0.0.1:2181
# 2023-11-10 18:24:18,881 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:onConnected(1394)) - Session establishment complete on server localhost/127.0.0.1:2181, sessionid = 0x100002cc3cc0009, negotiated timeout = 40000
# Bad line at offset: 288:
# No delimiter
# 2023-11-10 18:24:18,977 INFO  [LocalJobRunner Map Task Executor #0] mapred.LocalJobRunner (LocalJobRunner.java:statusUpdate(620)) -
# 2023-11-10 18:24:19,072 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2] zookeeper.ZooKeeper (ZooKeeper.java:close(1422)) - Session: 0x100002cc3cc0009 closed
# 2023-11-10 18:24:19,073 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x0499a2d2-EventThread] zookeeper.ClientCnxn (ClientCnxn.java:run(524)) - EventThread shut down for session: 0x100002cc3cc0009
# 2023-11-10 18:24:19,138 INFO  [LocalJobRunner Map Task Executor #0] mapred.Task (Task.java:done(1105)) - Task:attempt_local361175272_0001_m_000000_0 is done. And is in the process of committing
# 2023-11-10 18:24:19,165 INFO  [LocalJobRunner Map Task Executor #0] mapred.LocalJobRunner (LocalJobRunner.java:statusUpdate(620)) - map
# 2023-11-10 18:24:19,166 INFO  [LocalJobRunner Map Task Executor #0] mapred.Task (Task.java:sendDone(1243)) - Task 'attempt_local361175272_0001_m_000000_0' done.
# 2023-11-10 18:24:19,179 INFO  [LocalJobRunner Map Task Executor #0] mapred.Task (Task.java:done(1139)) - Final Counters for attempt_local361175272_0001_m_000000_0: Counters: 19
# 	File System Counters
# 		FILE: Number of bytes read=437241
# 		FILE: Number of bytes written=1020200
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=13
# 		Map output records=12
# 		Input split bytes=88
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		CPU time spent (ms)=470
# 		Physical memory (bytes) snapshot=280678400
# 		Virtual memory (bytes) snapshot=5173276672
# 		Total committed heap usage (bytes)=206831616
# 	ImportTsv
# 		Bad Lines=1
# 	File Input Format Counters
# 		Bytes Read=305
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-11-10 18:24:19,179 INFO  [LocalJobRunner Map Task Executor #0] mapred.LocalJobRunner (LocalJobRunner.java:run(276)) - Finishing task: attempt_local361175272_0001_m_000000_0
# 2023-11-10 18:24:19,179 INFO  [Thread-7] mapred.LocalJobRunner (LocalJobRunner.java:runTasks(485)) - map task executor complete.
# 2023-11-10 18:24:19,244 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4] zookeeper.ZooKeeper (ZooKeeper.java:close(1422)) - Session: 0x100002cc3cc0008 closed
# 2023-11-10 18:24:19,244 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x02562bd4-EventThread] zookeeper.ClientCnxn (ClientCnxn.java:run(524)) - EventThread shut down for session: 0x100002cc3cc0008
# 2023-11-10 18:24:19,616 INFO  [main] mapreduce.Job (Job.java:monitorAndPrintJob(1643)) - Job job_local361175272_0001 running in uber mode : false
# 2023-11-10 18:24:19,618 INFO  [main] mapreduce.Job (Job.java:monitorAndPrintJob(1650)) -  map 100% reduce 0%
# 2023-11-10 18:24:19,620 INFO  [main] mapreduce.Job (Job.java:monitorAndPrintJob(1661)) - Job job_local361175272_0001 completed successfully
# 2023-11-10 18:24:19,626 INFO  [main] mapreduce.Job (Job.java:monitorAndPrintJob(1668)) - Counters: 19
# 	File System Counters
# 		FILE: Number of bytes read=437241
# 		FILE: Number of bytes written=1020200
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=13
# 		Map output records=12
# 		Input split bytes=88
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		CPU time spent (ms)=470
# 		Physical memory (bytes) snapshot=280678400
# 		Virtual memory (bytes) snapshot=5173276672
# 		Total committed heap usage (bytes)=206831616
# 	ImportTsv
# 		Bad Lines=1
# 	File Input Format Counters
# 		Bytes Read=305
# 	File Output Format Counters
# 		Bytes Written=0

# %% [markdown]
# Print the entire content of the table using the **scan** command (notice that the output is ordered lexicographically based on the key).

# %%
# !echo "scan 'airtravel'" | hbase shell -n
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]
# 2023-11-10 18:25:25,588 INFO  [main] Configuration.deprecation (Configuration.java:logDeprecation(1294)) - hbase.client.pause.cqtbe is deprecated. Instead, use hbase.client.pause.server.overloaded
# 2023-11-10 18:25:25,685 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:zookeeper.version=3.5.7-f0fdd52973d373ffd9c86b81d99842dc2c7f660e, built on 02/10/2020 11:30 GMT
# 2023-11-10 18:25:25,686 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:host.name=8e95860f6443
# 2023-11-10 18:25:25,686 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.version=1.8.0_382
# 2023-11-10 18:25:25,686 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.vendor=Private Build
# 2023-11-10 18:25:25,686 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.home=/usr/lib/jvm/java-8-openjdk-amd64/jre
# 2023-11-10 18:25:25,686 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.class.path=/content/hbase-2.5.6//lib/ruby/jruby-complete-9.2.13.0.jar:/content/hbase-2.5.6//conf:/usr/lib/jvm/java-8-openjdk-amd64/lib/tools.jar:/content/hbase-2.5.6/:/content/hbase-2.5.6//lib/agrona-1.12.0.jar:/content/hbase-2.5.6//lib/aircompressor-0.24.jar:/content/hbase-2.5.6//lib/aopalliance-1.0.jar:/content/hbase-2.5.6//lib/apacheds-i18n-2.0.0-M15.jar:/content/hbase-2.5.6//lib/apacheds-kerberos-codec-2.0.0-M15.jar:/content/hbase-2.5.6//lib/api-asn1-api-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-i18n-1.0.0-M20.jar:/content/hbase-2.5.6//lib/api-util-1.0.0-M20.jar:/content/hbase-2.5.6//lib/asm-3.1.jar:/content/hbase-2.5.6//lib/avro-1.11.3.jar:/content/hbase-2.5.6//lib/brotli4j-1.11.0.jar:/content/hbase-2.5.6//lib/byte-buddy-1.9.10.jar:/content/hbase-2.5.6//lib/byte-buddy-agent-1.9.10.jar:/content/hbase-2.5.6//lib/caffeine-2.8.1.jar:/content/hbase-2.5.6//lib/checker-qual-3.1.0.jar:/content/hbase-2.5.6//lib/commons-cli-1.2.jar:/content/hbase-2.5.6//lib/commons-codec-1.15.jar:/content/hbase-2.5.6//lib/commons-collections-3.2.2.jar:/content/hbase-2.5.6//lib/commons-compress-1.21.jar:/content/hbase-2.5.6//lib/commons-configuration-1.6.jar:/content/hbase-2.5.6//lib/commons-crypto-1.1.0.jar:/content/hbase-2.5.6//lib/commons-csv-1.0.jar:/content/hbase-2.5.6//lib/commons-daemon-1.0.13.jar:/content/hbase-2.5.6//lib/commons-digester-1.8.jar:/content/hbase-2.5.6//lib/commons-io-2.11.0.jar:/content/hbase-2.5.6//lib/commons-lang-2.6.jar:/content/hbase-2.5.6//lib/commons-lang3-3.9.jar:/content/hbase-2.5.6//lib/commons-math3-3.6.1.jar:/content/hbase-2.5.6//lib/commons-net-3.1.jar:/content/hbase-2.5.6//lib/curator-client-4.2.0.jar:/content/hbase-2.5.6//lib/curator-framework-4.2.0.jar:/content/hbase-2.5.6//lib/curator-recipes-4.2.0.jar:/content/hbase-2.5.6//lib/disruptor-3.4.2.jar:/content/hbase-2.5.6//lib/ehcache-3.3.1.jar:/content/hbase-2.5.6//lib/error_prone_annotations-2.21.1.jar:/content/hbase-2.5.6//lib/fst-2.50.jar:/content/hbase-2.5.6//lib/geronimo-jcache_1.0_spec-1.0-alpha-1.jar:/content/hbase-2.5.6//lib/gson-2.2.4.jar:/content/hbase-2.5.6//lib/guava-11.0.2.jar:/content/hbase-2.5.6//lib/guice-3.0.jar:/content/hbase-2.5.6//lib/guice-servlet-3.0.jar:/content/hbase-2.5.6//lib/hadoop-annotations-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-auth-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-distcp-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-hdfs-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-app-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-core-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-hs-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-jobclient-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-mapreduce-client-shuffle-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-minicluster-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-api-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-client-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-registry-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-applicationhistoryservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-common-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-nodemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-resourcemanager-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-tests-2.10.2-tests.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-timelineservice-2.10.2.jar:/content/hbase-2.5.6//lib/hadoop-yarn-server-web-proxy-2.10.2.jar:/content/hbase-2.5.6//lib/hamcrest-core-1.3.jar:/content/hbase-2.5.6//lib/hb ...
# 2023-11-10 18:25:25,907 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.library.path=/usr/local/hadoop-3.3.6//lib/native
# 2023-11-10 18:25:25,907 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.io.tmpdir=/tmp
# 2023-11-10 18:25:25,907 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:java.compiler=<NA>
# 2023-11-10 18:25:25,907 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.name=Linux
# 2023-11-10 18:25:25,907 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.arch=amd64
# 2023-11-10 18:25:25,908 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.version=5.15.120+
# 2023-11-10 18:25:25,908 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.name=root
# 2023-11-10 18:25:25,908 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.home=/root
# 2023-11-10 18:25:25,908 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:user.dir=/content
# 2023-11-10 18:25:25,909 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.free=94MB
# 2023-11-10 18:25:25,909 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.max=3229MB
# 2023-11-10 18:25:25,909 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (Environment.java:logEnv(109)) - Client environment:os.memory.total=197MB
# 2023-11-10 18:25:25,913 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ZooKeeper (ZooKeeper.java:<init>(868)) - Initiating client connection, connectString=127.0.0.1:2181 sessionTimeout=90000 watcher=org.apache.hadoop.hbase.zookeeper.ReadOnlyZKClient$$Lambda$227/2005631145@73617114
# 2023-11-10 18:25:25,921 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] common.X509Util (X509Util.java:<clinit>(79)) - Setting -D jdk.tls.rejectClientInitiatedRenegotiation=true to disable client-initiated TLS renegotiation
# 2023-11-10 18:25:25,935 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ClientCnxnSocket (ClientCnxnSocket.java:initProperties(237)) - jute.maxbuffer value is 4194304 Bytes
# 2023-11-10 18:25:25,949 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501] zookeeper.ClientCnxn (ClientCnxn.java:initRequestTimeout(1653)) - zookeeper.request.timeout value is 0. feature enabled=
# 2023-11-10 18:25:25,971 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:logStartConnect(1112)) - Opening socket connection to server localhost/127.0.0.1:2181. Will not attempt to authenticate using SASL (unknown error)
# 2023-11-10 18:25:25,979 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:primeConnection(959)) - Socket connection established, initiating session, client: /127.0.0.1:58206, server: localhost/127.0.0.1:2181
# 2023-11-10 18:25:25,994 INFO  [ReadOnlyZKClient-127.0.0.1:2181@0x6f986501-SendThread(127.0.0.1:2181)] zookeeper.ClientCnxn (ClientCnxn.java:onConnected(1394)) - Session establishment complete on server localhost/127.0.0.1:2181, sessionid = 0x100002cc3cc000a, negotiated timeout = 40000
# hbase:001:0> scan 'airtravel'
# ROW                   COLUMN+CELL
#  "APR"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  348
#  "APR"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  396
#  "APR"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  461
#  "AUG"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  505
#  "AUG"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  559
#  "AUG"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  606
#  "DEC"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  337
#  "DEC"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  405
#  "DEC"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  432
#  "FEB"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  318
#  "FEB"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  342
#  "FEB"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  391
#  "JAN"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  340
#  "JAN"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  360
#  "JAN"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  417
#  "JUL"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  491
#  "JUL"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  548
#  "JUL"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  622
#  "JUN"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  435
#  "JUN"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  472
#  "JUN"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  535
#  "MAR"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  362
#  "MAR"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  406
#  "MAR"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  419
#  "MAY"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  363
#  "MAY"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  420
#  "MAY"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  472
#  "NOV"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  310
#  "NOV"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  362
#  "NOV"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  390
#  "OCT"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  359
#  "OCT"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  407
#  "OCT"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  461
#  "SEP"                column=years:1958, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  404
#  "SEP"                column=years:1959, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  463
#  "SEP"                column=years:1960, timestamp=2023-11-10T18:24:12.133, valu
#                       e=  508
# 12 row(s)
# Took 1.3803 seconds
# hbase:002:0>

# %% [markdown]
# # The HappyBase library
#
# Here, we will showcase how to use the **HappyBase** (https://happybase.readthedocs.io/en/latest/) library to interact with HBase from Python. For that, we will also make use of HBase's Thrift server, which provides APIs to interact with HBase from programming languages beyond Java.

# %% [markdown]
# First, stop HBase in order to install HappyBase and start Thrift.

# %%
# !stop-hbase.sh
# Out:
# stopping hbase..............
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]

# %% [markdown]
# Install HappyBase

# %%
# !pip install happybase
import happybase
# Out:
# Collecting happybase
#   Downloading happybase-1.2.0.tar.gz (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 895.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from happybase) (1.16.0)
# Collecting thriftpy2>=0.4 (from happybase)
#   Downloading thriftpy2-0.4.17.tar.gz (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.4/519.4 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ply<4.0,>=3.4 (from thriftpy2>=0.4->happybase)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.8 MB/s eta 0:00:00
# Building wheels for collected packages: happybase, thriftpy2
#   Building wheel for happybase (setup.py) ... done
#   Created wheel for happybase: filename=happybase-1.2.0-py2.py3-none-any.whl size=26602 sha256=27b079bccb8ba57a4b6351a2395963e239182f8d2dfd4f519a629693a010329a
#   Stored in directory: /root/.cache/pip/wheels/95/d9/40/aef1e677ca6b53d419ead4f533d2a44198a1ce0b7b36b2437f
#   Building wheel for thriftpy2 (pyproject.toml) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.4.17-cp310-cp310-linux_x86_64.whl size=1382275 sha256=3963752ee0c4b03ac5883aa821c4af0240af08bb9e3e6383af1e32eb1bc9c1a2
#   Stored in directory: /root/.cache/pip/wheels/b3/ca/c1/bd8e4cd94145e4e79882fdf705ca021a7a7632248ce6d1d4f4
# Successfully built happybase thriftpy2
# Installing collected packages: ply, thriftpy2, happybase
# Successfully installed happybase-1.2.0 ply-3.11 thriftpy2-0.4.17

# %% [markdown]
# Start Thrift and HBasee

# %%
# !hbase-daemon.sh start thrift
# Out:
# running thrift, logging to /content/hbase-2.5.6//logs/hbase--thrift-8e95860f6443.out

# %%
# !start-hbase.sh
# !jps
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]
# running master, logging to /content/hbase-2.5.6//logs/hbase--master-8e95860f6443.out
# 23825 ThriftServer
# 24242 Jps
# 24284 -- process information unavailable

# %% [markdown]
# ### Interacting with HBase programatically

# %% [markdown]
# Create a connection object

# %%
kxn = happybase.Connection('localhost',9090,autoconnect=False)
kxn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f24890967d91> in <cell line: 1>()
# ----> 1 kxn = happybase.Connection('localhost',9090,autoconnect=False)
#       2 kxn
#
# NameError: name 'happybase' is not defined

# %% [markdown]
# Display the tables (equivalent to the **list** command from the shell)

# %%
kxn.open()
kxn.tables()
# Out:
# [b'airtravel']

# %% [markdown]
# Create a table

# %%
kxn.open()
#Drop Table
kxn.disable_table('airtravel')
kxn.delete_table('airtravel')
#Create Table
kxn.create_table(
    'airtravel',
    {
        'years': dict()
    }
)
kxn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-55278fe8727d> in <cell line: 1>()
# ----> 1 kxn.open()
#       2 #Drop Table
#       3 kxn.disable_table('airtravel')
#       4 kxn.delete_table('airtravel')
#       5 #Create Table
#
# NameError: name 'kxn' is not defined

# %% [markdown]
# Get the reference to the table

# %%
kxn.open()
tAirtravel = kxn.table('airtravel')
kxn.close()

# %% [markdown]
# Put some data. Elements are inserted as key-value pairs, where the key must contain the column family and the qualifier names.

# %%
kxn.open()
b = tAirtravel.batch()
b.put(b'JAN',{b'years:1958': b'340', b'years:1959': b'360', b'years:1960': b'417'})
b.put(b'FEB',{b'years:1958': b'318', b'years:1959': b'342', b'years:1960': b'391'})
b.put(b'MAR',{b'years:1958': b'362', b'years:1959': b'406', b'years:1960': b'419'})
b.send()
kxn.close()

# %% [markdown]
# Scan the complete table

# %%
kxn.open()
for key, data in tAirtravel.scan():
    print(key, data)
kxn.close()
# Out:
# b'FEB' {b'years:1958': b'318', b'years:1959': b'342', b'years:1960': b'391'}
# b'JAN' {b'years:1958': b'340', b'years:1959': b'360', b'years:1960': b'417'}
# b'MAR' {b'years:1958': b'362', b'years:1959': b'406', b'years:1960': b'419'}

# %% [markdown]
# Scan the table from the key "FEB" to the key "JAN", here we specify the range via the **row_start** and **row_stop**. Note that the **row_start** is inclusive, while **row_stop** is exclusive. That is why if we want to include the key "JAN", we need to add some extra character.

# %%
kxn.open()
for key, data in tAirtravel.scan(row_start=b'FEB', row_stop=b'JAN_'):
    print(key, data)
kxn.close()
# Out:
# b'FEB' {b'years:1958': b'318', b'years:1959': b'342', b'years:1960': b'391'}
# b'JAN' {b'years:1958': b'340', b'years:1959': b'360', b'years:1960': b'417'}

# %% [markdown]
# Scan a row prefix

# %%
kxn.open()
for key, data in tAirtravel.scan(row_prefix=b'M'):
    print(key, data)
kxn.close()
# Out:
# b'MAR' {b'years:1958': b'362', b'years:1959': b'406', b'years:1960': b'419'}

# %% [markdown]
# Scan a subset of column families

# %%
kxn.open()
for key, data in tAirtravel.scan(columns=['years']):
    print(key, data)
kxn.close()
# Out:
# b'FEB' {b'years:1958': b'318', b'years:1959': b'342', b'years:1960': b'391'}
# b'JAN' {b'years:1958': b'340', b'years:1959': b'360', b'years:1960': b'417'}
# b'MAR' {b'years:1958': b'362', b'years:1959': b'406', b'years:1960': b'419'}

# %% [markdown]
# # On the key design
#
# Key design is an essential aspect in HBase: i.e., decide how the row keys are going to be defined. Range queries can benefit from the B+ tree and the clustered index and drastically improve performance. As a simple example, imagine a query that uses a specific attribute to filter out the rows quite often and, accordingly, we decide that attribute to be the key. Since HBase indexes the key, we can use the index to perform the selections.
# Key design is an important aspect of HBase (and in general, of many NOSQL database systems). So let us exemplify its relevance. Suppose a use case where data is generated every second and we decide to use the timestamp as row key in HBase.

# %%
import time
import random

# %%
kxn.open()
#kxn.disable_table('sensor_data')
#kxn.delete_table('sensor_data')
kxn.create_table(
    'sensor_data',
    {
        'measurements': dict()
    }
)
kxn.close()

# %%
kxn.open()
tSensorData = kxn.table('sensor_data')
kxn.close()

# %%
kxn.open()
b = tSensorData.batch()
for i in range(10):
  b.put(bytes(str(time.time()),'UTF-8'),
   {b'measurements:humidity':bytes(str(random.randint(0,100)),'UTF-8'),
    b'measurements:temperature':bytes(str(random.randint(0,30)),'UTF-8') })
  time.sleep(1)
b.send()
kxn.close()

# %%
kxn.open()
for key, data in tSensorData.scan():
    print(key, data)
kxn.close()
# Out:
# b'1699641566.0903993' {b'measurements:humidity': b'15', b'measurements:temperature': b'28'}
# b'1699641567.091501' {b'measurements:humidity': b'17', b'measurements:temperature': b'3'}
# b'1699641568.0924923' {b'measurements:humidity': b'86', b'measurements:temperature': b'8'}
# b'1699641569.0934975' {b'measurements:humidity': b'84', b'measurements:temperature': b'8'}
# b'1699641570.0945022' {b'measurements:humidity': b'71', b'measurements:temperature': b'13'}
# b'1699641571.0955389' {b'measurements:humidity': b'6', b'measurements:temperature': b'26'}
# b'1699641572.0965' {b'measurements:humidity': b'70', b'measurements:temperature': b'30'}
# b'1699641573.0976734' {b'measurements:humidity': b'27', b'measurements:temperature': b'29'}
# b'1699641574.098819' {b'measurements:humidity': b'25', b'measurements:temperature': b'21'}
# b'1699641575.0995371' {b'measurements:humidity': b'1', b'measurements:temperature': b'6'}

# %% [markdown]
# Do you think timestamp is a wise decision for the row key? Justify your answer.
