# %% [markdown]
# #CBDE Lab 4 (part 1) - The Hadoop ecosystem (Hadoop & HBase)
#
# #Assignment

# %% [markdown]
# ##Setup environment
#
# First, we will download and setup Hadoop and HBase. This notebook is configured to use the following versions of the systems:
# *   Java JDK 8
# *   Hadoop 3.3.6
# *   HBase 2.5.6
#
# In case some of the downloads fail (due to changes in versioning) the download link should be updated as well as all references to the version used.

# %% [markdown]
# ### Hadoop
#
# Download and install Hadoop

# %%
#Setup JVM 8 (JVM 11 might cause incompatibility issues)
# !apt-get update > /dev/null
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# Download the latest version of Hadoop
# !wget https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Unzip it
# the tar command with the -x flag to extract, -z to uncompress, -v for verbose output, and -f to specify that we are extracting from a file
# !tar -xzf hadoop-3.3.6.tar.gz
#copy hadoop file to user/local
# !mv hadoop-3.3.6/ /usr/local/
# Out:
# --2023-11-14 21:17:48--  https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 730107476 (696M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.6.tar.gz.1’
#
# hadoop-3.3.6.tar.gz 100%[===================>] 696.28M   111MB/s    in 5.6s
#
# 2023-11-14 21:17:53 (125 MB/s) - ‘hadoop-3.3.6.tar.gz.1’ saved [730107476/730107476]
#
# mv: cannot move 'hadoop-3.3.6/' to '/usr/local/hadoop-3.3.6': Directory not empty

# %% [markdown]
# Set environment variables

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop-3.3.6/"

# %%
# Add Hadoop BIN to PATH
current_path = os.getenv('PATH')
new_path = current_path+':/usr/local/hadoop-3.3.6/bin/'
os.environ["PATH"] = new_path

# %% [markdown]
# ### HBase
#
# Download and install HBase

# %%
# Get the latest HBase version
# !wget https://dlcdn.apache.org/hbase/2.5.6/hbase-2.5.6-bin.tar.gz
# !tar xzf hbase-2.5.6-bin.tar.gz
# Out:
# --2023-11-14 21:19:15--  https://dlcdn.apache.org/hbase/2.5.6/hbase-2.5.6-bin.tar.gz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 314596103 (300M) [application/x-gzip]
# Saving to: ‘hbase-2.5.6-bin.tar.gz.1’
#
# hbase-2.5.6-bin.tar 100%[===================>] 300.02M   171MB/s    in 1.8s
#
# 2023-11-14 21:19:17 (171 MB/s) - ‘hbase-2.5.6-bin.tar.gz.1’ saved [314596103/314596103]

# %% [markdown]
# Set environment variables

# %%
os.environ["HBASE_HOME"] = "/content/hbase-2.5.6/"
# !echo $HBASE_HOME
# Out:
# /content/hbase-2.5.6/

# %%
# Add HBase BIN to PATH
current_path = os.getenv('PATH')
new_path = current_path+':/content/hbase-2.5.6/bin'
os.environ["PATH"] = new_path
# !echo $PATH
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/usr/local/hadoop-3.3.6/bin/:/content/hbase-2.5.6/bin:/usr/local/hadoop-3.3.6/bin/:/content/hbase-2.5.6/bin

# %% [markdown]
# ### Start HBase server

# %%
# !pip install happybase
import happybase
# !hbase-daemon.sh start thrift
# !start-hbase.sh
# !jps
# Out:
# Requirement already satisfied: happybase in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from happybase) (1.16.0)
# Requirement already satisfied: thriftpy2>=0.4 in /usr/local/lib/python3.10/dist-packages (from happybase) (0.4.17)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.10/dist-packages (from thriftpy2>=0.4->happybase) (3.11)
# thrift running as process 1860. Stop it first.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/local/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hbase-2.5.6/lib/client-facing-thirdparty/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Reload4jLoggerFactory]
# master running as process 2191. Stop it first.
# 1860 ThriftServer
# 10300 Jps
# 2191 HMaster

# %% [markdown]
# # Dataset description
#
# Both parts of this session consist on processing and analyzing a dataset containing information from the *Census Income Dataset* (https://archive.ics.uci.edu/dataset/2/adult). The schema and characteristics of the dataset are as follows:
#
# 1. **age**: continuous.
# 2. **workclass**: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# 3. **fnlwgt**: continuous.
# 4. **education**: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# 5. **education-num**: continuous.
# 6. **marital-status**: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# 7. **occupation**: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# 8. **relationship**: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# 9. **race**: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# 10. **sex**: Female, Male.
# 11. **capital-gain**: continuous.
# 12. **capital-loss**: continuous.
# 13. **hours-per-week**: continuous.
# 14. **native-country**: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# 15. **income**: >50K, <=50K.

# %%
# !wget https://archive.ics.uci.edu/static/public/2/adult.zip
# !unzip adult.zip
# Out:
# --2023-11-14 21:19:46--  https://archive.ics.uci.edu/static/public/2/adult.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘adult.zip.1’
#
# adult.zip.1             [ <=>                ] 605.70K  --.-KB/s    in 0.1s
#
# 2023-11-14 21:19:46 (4.24 MB/s) - ‘adult.zip.1’ saved [620237]
#
# Archive:  adult.zip
# replace Index? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Index
# replace adult.data? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: adult.data
#   inflating: adult.names
#   inflating: adult.test
#   inflating: old.adult.names

# %%
import csv, itertools
dataset = []
schema = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','income']

with open('adult.data') as csvfile:
    for row in itertools.islice(csv.DictReader(csvfile,fieldnames=schema), 100):
      for k,v in row.items():
        row[k] = v.replace(' ', '')
      dataset.append(row)

dataset[0]
# Out:
# {'age': '39',
#  'workclass': 'State-gov',
#  'fnlwgt': '77516',
#  'education': 'Bachelors',
#  'education-num': '13',
#  'marital-status': 'Never-married',
#  'occupation': 'Adm-clerical',
#  'relationship': 'Not-in-family',
#  'race': 'White',
#  'sex': 'Male',
#  'capital-gain': '2174',
#  'capital-loss': '0',
#  'hours-per-week': '40',
#  'native-country': 'United-States',
#  'income': '<=50K'}

# %%
kxn = happybase.Connection('localhost',9090,autoconnect=False)
kxn

# %% [markdown]
# # Exercise 1 - HBase Vertical Partitioning
#
# In this exercise, we are going to focus on the concept of family of HBase, which allows us to vertically fragment instances. Thus, we will programatically define the vertical fragments and access them.
#
# For that, assume a query $Q_1$ that needs to scan the whole table but only fetching attributes *education*, *occupation* and *hours-per-week*.  The equivalent SQL expression for that query would be:
#
# ```sql
# SELECT education, occupation, hours-per-week
# FROM adult
# ```

# %% [markdown]
# ## 1.1 Table creation
#
# Provide below the code to create the best table layout (i.e., define the appropriate families) to accomodate such query.

# %%
kxn.open()

# Elimina la taula si existeix
table_name = 'census_data'
try:
    kxn.disable_table(table_name)
    kxn.delete_table(table_name)
    print(f'Taula "{table_name}" desactivada i eliminada amb èxit.')
except Exception as e:

    #Si la taula 'table_name' encara no ha estat creada mai donarà aquesta excepció
    print(f'Error mentre es desactivava/eliminava la taula: {e}')



# Crear taula
kxn.create_table(
    table_name,
    {
        'education': dict(),
        'occupation': dict(),
        'hours-per-week': dict()
    }
)

# Tanca la connexió
kxn.close()

# Mostra les taules per verificar la creació
kxn.open()
print("Taules:", kxn.tables())


# Obté una referència a la taula
kxn.open()
census_table = kxn.table(table_name)
kxn.close()
# Out:
# Taula "census_data" desactivada i eliminada amb èxit.
# Taules: [b'census_data', b'census_data_q2']

# %% [markdown]
# ## 1.2 Populating the table
#
# Provide below the code to populate the table you previously created with the data contained in the **data** array.
#
# In this exercise **you do not need to be concerned** with the choice of key. Thus, you can use an autogenerated timestamp just like the training.

# %%
import time
import random

kxn.open()
b = census_table.batch()
for idx, data_row in enumerate(dataset):
    # Utilitza time.time() com a clau (timestamp)
    key = bytes(str(time.time()), 'UTF-8')

    # Prepara les dades per a la inserció
    data = {
        b'education:': data_row['education'].encode(),
        b'occupation:': data_row['occupation'].encode(),
        b'hours-per-week:': str(data_row['hours-per-week']).encode()
    }

    # Insereix les dades a la taula
    b.put(key, data)

    print(f"Fila {idx + 1} inserida amb èxit.")

    # Dorm per una breu durada (0.1 segon en aquest exemple)
    time.sleep(0.1)

    # Envia l'actualització per lots
    b.send()

kxn.close()
# Out:
# Fila 1 inserida amb èxit.
# Fila 2 inserida amb èxit.
# Fila 3 inserida amb èxit.
# Fila 4 inserida amb èxit.
# Fila 5 inserida amb èxit.
# Fila 6 inserida amb èxit.
# Fila 7 inserida amb èxit.
# Fila 8 inserida amb èxit.
# Fila 9 inserida amb èxit.
# Fila 10 inserida amb èxit.
# Fila 11 inserida amb èxit.
# Fila 12 inserida amb èxit.
# Fila 13 inserida amb èxit.
# Fila 14 inserida amb èxit.
# Fila 15 inserida amb èxit.
# Fila 16 inserida amb èxit.
# Fila 17 inserida amb èxit.
# Fila 18 inserida amb èxit.
# Fila 19 inserida amb èxit.
# Fila 20 inserida amb èxit.
# Fila 21 inserida amb èxit.
# Fila 22 inserida amb èxit.
# Fila 23 inserida amb èxit.
# Fila 24 inserida amb èxit.
# Fila 25 inserida amb èxit.
# Fila 26 inserida amb èxit.
# Fila 27 inserida amb èxit.
# Fila 28 inserida amb èxit.
# Fila 29 inserida amb èxit.
# Fila 30 inserida amb èxit.
# Fila 31 inserida amb èxit.
# Fila 32 inserida amb èxit.
# Fila 33 inserida amb èxit.
# Fila 34 inserida amb èxit.
# Fila 35 inserida amb èxit.
# Fila 36 inserida amb èxit.
# Fila 37 inserida amb èxit.
# Fila 38 inserida amb èxit.
# Fila 39 inserida amb èxit.
# Fila 40 inserida amb èxit.
# Fila 41 inserida amb èxit.
# Fila 42 inserida amb èxit.
# Fila 43 inserida amb èxit.
# Fila 44 inserida amb èxit.
# Fila 45 inserida amb èxit.
# Fila 46 inserida amb èxit.
# Fila 47 inserida amb èxit.
# Fila 48 inserida amb èxit.
# Fila 49 inserida amb èxit.
# Fila 50 inserida amb èxit.
# Fila 51 inserida amb èxit.
# Fila 52 inserida amb èxit.
# Fila 53 inserida amb èxit.
# Fila 54 inserida amb èxit.
# Fila 55 inserida amb èxit.
# Fila 56 inserida amb èxit.
# Fila 57 inserida amb èxit.
# Fila 58 inserida amb èxit.
# Fila 59 inserida amb èxit.
# Fila 60 inserida amb èxit.
# Fila 61 inserida amb èxit.
# Fila 62 inserida amb èxit.
# Fila 63 inserida amb èxit.
# Fila 64 inserida amb èxit.
# Fila 65 inserida amb èxit.
# Fila 66 inserida amb èxit.
# Fila 67 inserida amb èxit.
# Fila 68 inserida amb èxit.
# Fila 69 inserida amb èxit.
# Fila 70 inserida amb èxit.
# Fila 71 inserida amb èxit.
# Fila 72 inserida amb èxit.
# Fila 73 inserida amb èxit.
# Fila 74 inserida amb èxit.
# Fila 75 inserida amb èxit.
# Fila 76 inserida amb èxit.
# Fila 77 inserida amb èxit.
# Fila 78 inserida amb èxit.
# Fila 79 inserida amb èxit.
# Fila 80 inserida amb èxit.
# Fila 81 inserida amb èxit.
# Fila 82 inserida amb èxit.
# Fila 83 inserida amb èxit.
# Fila 84 inserida amb èxit.
# Fila 85 inserida amb èxit.
# Fila 86 inserida amb èxit.
# Fila 87 inserida amb èxit.
# Fila 88 inserida amb èxit.
# Fila 89 inserida amb èxit.
# Fila 90 inserida amb èxit.
# Fila 91 inserida amb èxit.
# Fila 92 inserida amb èxit.
# Fila 93 inserida amb èxit.
# Fila 94 inserida amb èxit.
# Fila 95 inserida amb èxit.
# Fila 96 inserida amb èxit.
# Fila 97 inserida amb èxit.
# Fila 98 inserida amb èxit.
# Fila 99 inserida amb èxit.
# Fila 100 inserida amb èxit.

# %% [markdown]
# ## 1.3 Scanning the table
#
# Provide below the code to implement $Q_1$

# %%
kxn.open()

# Escaneja la taula i imprimeix totes les dades
for key, data in census_table.scan():
    print(key.decode('UTF-8'), data)

# Tanca la connexió
kxn.close()
# Out:
# 1699998385.9119892 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Adm-clerical'}
# 1699998386.027083 {b'education:': b'Bachelors', b'hours-per-week:': b'13', b'occupation:': b'Exec-managerial'}
# 1699998386.133255 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Handlers-cleaners'}
# 1699998386.2505035 {b'education:': b'11th', b'hours-per-week:': b'40', b'occupation:': b'Handlers-cleaners'}
# 1699998386.3564887 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Prof-specialty'}
# 1699998386.4622467 {b'education:': b'Masters', b'hours-per-week:': b'40', b'occupation:': b'Exec-managerial'}
# 1699998386.5674853 {b'education:': b'9th', b'hours-per-week:': b'16', b'occupation:': b'Other-service'}
# 1699998386.672686 {b'education:': b'HS-grad', b'hours-per-week:': b'45', b'occupation:': b'Exec-managerial'}
# 1699998386.7909224 {b'education:': b'Masters', b'hours-per-week:': b'50', b'occupation:': b'Prof-specialty'}
# 1699998386.8963299 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Exec-managerial'}
# 1699998387.0016842 {b'education:': b'Some-college', b'hours-per-week:': b'80', b'occupation:': b'Exec-managerial'}
# 1699998387.114452 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Prof-specialty'}
# 1699998387.2198215 {b'education:': b'Bachelors', b'hours-per-week:': b'30', b'occupation:': b'Adm-clerical'}
# 1699998387.3260562 {b'education:': b'Assoc-acdm', b'hours-per-week:': b'50', b'occupation:': b'Sales'}
# 1699998387.4307299 {b'education:': b'Assoc-voc', b'hours-per-week:': b'40', b'occupation:': b'Craft-repair'}
# 1699998387.5346212 {b'education:': b'7th-8th', b'hours-per-week:': b'45', b'occupation:': b'Transport-moving'}
# 1699998387.6390262 {b'education:': b'HS-grad', b'hours-per-week:': b'35', b'occupation:': b'Farming-fishing'}
# 1699998387.7430449 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Machine-op-inspct'}
# 1699998387.847063 {b'education:': b'11th', b'hours-per-week:': b'50', b'occupation:': b'Sales'}
# 1699998387.9516351 {b'education:': b'Masters', b'hours-per-week:': b'45', b'occupation:': b'Exec-managerial'}
# 1699998388.0577753 {b'education:': b'Doctorate', b'hours-per-week:': b'60', b'occupation:': b'Prof-specialty'}
# 1699998388.1620054 {b'education:': b'HS-grad', b'hours-per-week:': b'20', b'occupation:': b'Other-service'}
# 1699998388.2683196 {b'education:': b'9th', b'hours-per-week:': b'40', b'occupation:': b'Farming-fishing'}
# 1699998388.3735685 {b'education:': b'11th', b'hours-per-week:': b'40', b'occupation:': b'Transport-moving'}
# 1699998388.4881167 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Tech-support'}
# 1699998388.598001 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Tech-support'}
# 1699998388.7060826 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Craft-repair'}
# 1699998388.812072 {b'education:': b'Some-college', b'hours-per-week:': b'60', b'occupation:': b'?'}
# 1699998388.9229124 {b'education:': b'HS-grad', b'hours-per-week:': b'80', b'occupation:': b'Exec-managerial'}
# 1699998389.0430841 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Craft-repair'}
# 1699998389.1491547 {b'education:': b'Assoc-acdm', b'hours-per-week:': b'52', b'occupation:': b'Protective-serv'}
# 1699998389.254753 {b'education:': b'Some-college', b'hours-per-week:': b'44', b'occupation:': b'Sales'}
# 1699998389.3594615 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Exec-managerial'}
# 1699998389.4640248 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'Adm-clerical'}
# 1699998389.5679193 {b'education:': b'Some-college', b'hours-per-week:': b'15', b'occupation:': b'Other-service'}
# 1699998389.671648 {b'education:': b'11th', b'hours-per-week:': b'40', b'occupation:': b'Machine-op-inspct'}
# 1699998389.7757769 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'Machine-op-inspct'}
# 1699998389.8799407 {b'education:': b'HS-grad', b'hours-per-week:': b'25', b'occupation:': b'Adm-clerical'}
# 1699998389.9836733 {b'education:': b'Some-college', b'hours-per-week:': b'38', b'occupation:': b'Sales'}
# 1699998390.0871708 {b'education:': b'Assoc-acdm', b'hours-per-week:': b'40', b'occupation:': b'Prof-specialty'}
# 1699998390.1926525 {b'education:': b'9th', b'hours-per-week:': b'43', b'occupation:': b'Machine-op-inspct'}
# 1699998390.2966843 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Prof-specialty'}
# 1699998390.4004633 {b'education:': b'Bachelors', b'hours-per-week:': b'50', b'occupation:': b'Tech-support'}
# 1699998390.505492 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Adm-clerical'}
# 1699998390.6099157 {b'education:': b'HS-grad', b'hours-per-week:': b'35', b'occupation:': b'Handlers-cleaners'}
# 1699998390.7245102 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Prof-specialty'}
# 1699998390.8296704 {b'education:': b'HS-grad', b'hours-per-week:': b'38', b'occupation:': b'Machine-op-inspct'}
# 1699998390.9343135 {b'education:': b'Masters', b'hours-per-week:': b'40', b'occupation:': b'Exec-managerial'}
# 1699998391.0389419 {b'education:': b'Assoc-voc', b'hours-per-week:': b'40', b'occupation:': b'Craft-repair'}
# 1699998391.143503 {b'education:': b'Assoc-voc', b'hours-per-week:': b'43', b'occupation:': b'Prof-specialty'}
# 1699998391.2488782 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'Exec-managerial'}
# 1699998391.3534844 {b'education:': b'HS-grad', b'hours-per-week:': b'30', b'occupation:': b'Other-service'}
# 1699998391.4587827 {b'education:': b'Prof-school', b'hours-per-week:': b'60', b'occupation:': b'Prof-specialty'}
# 1699998391.5625777 {b'education:': b'Bachelors', b'hours-per-week:': b'55', b'occupation:': b'Exec-managerial'}
# 1699998391.6673813 {b'education:': b'HS-grad', b'hours-per-week:': b'60', b'occupation:': b'Exec-managerial'}
# 1699998391.771329 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'Tech-support'}
# 1699998391.8750916 {b'education:': b'5th-6th', b'hours-per-week:': b'40', b'occupation:': b'Machine-op-inspct'}
# 1699998391.97856 {b'education:': b'Assoc-voc', b'hours-per-week:': b'40', b'occupation:': b'Other-service'}
# 1699998392.085411 {b'education:': b'HS-grad', b'hours-per-week:': b'48', b'occupation:': b'Adm-clerical'}
# 1699998392.1896923 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Machine-op-inspct'}
# 1699998392.2942116 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Sales'}
# 1699998392.398806 {b'education:': b'7th-8th', b'hours-per-week:': b'40', b'occupation:': b'?'}
# 1699998392.5037975 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Transport-moving'}
# 1699998392.6084802 {b'education:': b'Doctorate', b'hours-per-week:': b'45', b'occupation:': b'Prof-specialty'}
# 1699998392.7135897 {b'education:': b'Some-college', b'hours-per-week:': b'58', b'occupation:': b'Tech-support'}
# 1699998392.818186 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Craft-repair'}
# 1699998392.923577 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'Adm-clerical'}
# 1699998393.0279858 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Adm-clerical'}
# 1699998393.1328027 {b'education:': b'Some-college', b'hours-per-week:': b'50', b'occupation:': b'Exec-managerial'}
# 1699998393.2373245 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'?'}
# 1699998393.342835 {b'education:': b'Some-college', b'hours-per-week:': b'32', b'occupation:': b'Prof-specialty'}
# 1699998393.4475482 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Sales'}
# 1699998393.5524726 {b'education:': b'Bachelors', b'hours-per-week:': b'70', b'occupation:': b'Sales'}
# 1699998393.6575682 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'Machine-op-inspct'}
# 1699998393.7627487 {b'education:': b'Some-college', b'hours-per-week:': b'20', b'occupation:': b'Prof-specialty'}
# 1699998393.8680568 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Other-service'}
# 1699998393.9731898 {b'education:': b'Assoc-acdm', b'hours-per-week:': b'40', b'occupation:': b'Adm-clerical'}
# 1699998394.077815 {b'education:': b'10th', b'hours-per-week:': b'2', b'occupation:': b'?'}
# 1699998394.1831431 {b'education:': b'11th', b'hours-per-week:': b'22', b'occupation:': b'Other-service'}
# 1699998394.2885003 {b'education:': b'7th-8th', b'hours-per-week:': b'40', b'occupation:': b'Farming-fishing'}
# 1699998394.3937008 {b'education:': b'HS-grad', b'hours-per-week:': b'30', b'occupation:': b'Sales'}
# 1699998394.498239 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Other-service'}
# 1699998394.603138 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Other-service'}
# 1699998394.708379 {b'education:': b'HS-grad', b'hours-per-week:': b'48', b'occupation:': b'Sales'}
# 1699998394.8119097 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Craft-repair'}
# 1699998394.9162676 {b'education:': b'HS-grad', b'hours-per-week:': b'35', b'occupation:': b'Sales'}
# 1699998395.0201766 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Protective-serv'}
# 1699998395.124565 {b'education:': b'Masters', b'hours-per-week:': b'50', b'occupation:': b'Prof-specialty'}
# 1699998395.2293255 {b'education:': b'9th', b'hours-per-week:': b'40', b'occupation:': b'Sales'}
# 1699998395.3329592 {b'education:': b'Doctorate', b'hours-per-week:': b'50', b'occupation:': b'Prof-specialty'}
# 1699998395.4375532 {b'education:': b'Assoc-voc', b'hours-per-week:': b'40', b'occupation:': b'Prof-specialty'}
# 1699998395.5425448 {b'education:': b'Some-college', b'hours-per-week:': b'40', b'occupation:': b'Craft-repair'}
# 1699998395.6475856 {b'education:': b'Some-college', b'hours-per-week:': b'25', b'occupation:': b'Machine-op-inspct'}
# 1699998395.7532125 {b'education:': b'HS-grad', b'hours-per-week:': b'35', b'occupation:': b'Sales'}
# 1699998395.857794 {b'education:': b'Bachelors', b'hours-per-week:': b'40', b'occupation:': b'Protective-serv'}
# 1699998395.962462 {b'education:': b'Some-college', b'hours-per-week:': b'50', b'occupation:': b'Handlers-cleaners'}
# 1699998396.0702484 {b'education:': b'Doctorate', b'hours-per-week:': b'60', b'occupation:': b'Prof-specialty'}
# 1699998396.1750047 {b'education:': b'Some-college', b'hours-per-week:': b'48', b'occupation:': b'Sales'}
# 1699998396.280151 {b'education:': b'Assoc-acdm', b'hours-per-week:': b'40', b'occupation:': b'Exec-managerial'}
# 1699998396.3845444 {b'education:': b'HS-grad', b'hours-per-week:': b'40', b'occupation:': b'Other-service'}

# %% [markdown]
# # Exercise 2 - HBase Key Design

# %% [markdown]
# This exercise asks you to design the key of the table to benefit from the distributed B-tree of HBase and avoid table scans when doing specific searches. Thus, assume a query $Q_2$ that retrieves all attributes where native-country = 'United-States' and occupation = 'Tech-support' = 0. The equivalent SQL expression for that query would be:
#
# ```sql
# SELECT *
# FROM adult
# WHERE native-country = 'United-States' AND occupation = 'Tech-support'
# ```
#
# For this exercise, you can recreate the table from the **data** array with a single column family (provide the code below).

# %%
kxn.open()

# Elimina la taula si existeix
table_name = 'census_data_q2'
try:
    kxn.disable_table(table_name)
    kxn.delete_table(table_name)
    print(f'Taula "{table_name}" desactivada i eliminada amb èxit.')
except Exception as e:

    #Si la taula 'table_name' encara no ha estat creada mai donarà aquesta excepció
    print(f'Error mentre es desactivava/eliminava la taula: {e}')

# Crea la taula amb una única família de columnes
try:
    kxn.create_table(
        table_name,
        {
            'data': dict()
        }
    )
    print(f'Taula "{table_name}" creada amb èxit amb una única família de columnes.')
except Exception as e:
    print(f'Error mentre es creava la taula: {e}')


# Obté una referència a la taula
kxn.open()
census_table_q2 = kxn.table(table_name)
kxn.close()
# Out:
# Taula "census_data_q2" desactivada i eliminada amb èxit.
# Taula "census_data_q2" creada amb èxit amb una única família de columnes.

# %% [markdown]
# ## 2.1 Key creation
#
# Provide below the code to populate the table so that it generates the most appropriate key design to efficiently answer $Q_2$.

# %%
kxn.open()

b = census_table_q2.batch()
for idx, data_row in enumerate(dataset):
    # Dissenyar la clau per respondre eficientment a la Q2: "<native-country>_<occupation>_<timestamp>"
    key = f"{data_row['native-country']}_{data_row['occupation']}_{int(time.time() * 1000)}"

    # Prepara les dades per a la inserció
    data = {
        b'data:age': data_row['age'].encode(),
        b'data:workclass': data_row['workclass'].encode(),
        b'data:fnlwgt': data_row['fnlwgt'].encode(),
        # Inclou altres columnes segons sigui necessari
    }

    # Insereix les dades a la taula
    b.put(key.encode(), data)

    print(f"Fila {idx + 1} inserida amb èxit amb la clau: {key}")

    # Dorm per una breu durada (0.1 segon en aquest exemple)
    time.sleep(0.1)

# Envia l'actualització per lots
b.send()

kxn.close()
# Out:
# Fila 1 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998411975
# Fila 2 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998412076
# Fila 3 inserida amb èxit amb la clau: United-States_Handlers-cleaners_1699998412177
# Fila 4 inserida amb èxit amb la clau: United-States_Handlers-cleaners_1699998412277
# Fila 5 inserida amb èxit amb la clau: Cuba_Prof-specialty_1699998412378
# Fila 6 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998412478
# Fila 7 inserida amb èxit amb la clau: Jamaica_Other-service_1699998412578
# Fila 8 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998412679
# Fila 9 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998412779
# Fila 10 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998412879
# Fila 11 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998412980
# Fila 12 inserida amb èxit amb la clau: India_Prof-specialty_1699998413080
# Fila 13 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998413180
# Fila 14 inserida amb èxit amb la clau: United-States_Sales_1699998413281
# Fila 15 inserida amb èxit amb la clau: ?_Craft-repair_1699998413381
# Fila 16 inserida amb èxit amb la clau: Mexico_Transport-moving_1699998413482
# Fila 17 inserida amb èxit amb la clau: United-States_Farming-fishing_1699998413582
# Fila 18 inserida amb èxit amb la clau: United-States_Machine-op-inspct_1699998413682
# Fila 19 inserida amb èxit amb la clau: United-States_Sales_1699998413783
# Fila 20 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998413884
# Fila 21 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998413985
# Fila 22 inserida amb èxit amb la clau: United-States_Other-service_1699998414085
# Fila 23 inserida amb èxit amb la clau: United-States_Farming-fishing_1699998414185
# Fila 24 inserida amb èxit amb la clau: United-States_Transport-moving_1699998414286
# Fila 25 inserida amb èxit amb la clau: United-States_Tech-support_1699998414386
# Fila 26 inserida amb èxit amb la clau: United-States_Tech-support_1699998414486
# Fila 27 inserida amb èxit amb la clau: United-States_Craft-repair_1699998414587
# Fila 28 inserida amb èxit amb la clau: South_?_1699998414687
# Fila 29 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998414788
# Fila 30 inserida amb èxit amb la clau: United-States_Craft-repair_1699998414888
# Fila 31 inserida amb èxit amb la clau: United-States_Protective-serv_1699998414988
# Fila 32 inserida amb èxit amb la clau: United-States_Sales_1699998415089
# Fila 33 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998415189
# Fila 34 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998415290
# Fila 35 inserida amb èxit amb la clau: United-States_Other-service_1699998415390
# Fila 36 inserida amb èxit amb la clau: Puerto-Rico_Machine-op-inspct_1699998415490
# Fila 37 inserida amb èxit amb la clau: United-States_Machine-op-inspct_1699998415591
# Fila 38 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998415691
# Fila 39 inserida amb èxit amb la clau: ?_Sales_1699998415791
# Fila 40 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998415892
# Fila 41 inserida amb èxit amb la clau: United-States_Machine-op-inspct_1699998415992
# Fila 42 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998416092
# Fila 43 inserida amb èxit amb la clau: United-States_Tech-support_1699998416193
# Fila 44 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998416293
# Fila 45 inserida amb èxit amb la clau: United-States_Handlers-cleaners_1699998416393
# Fila 46 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998416494
# Fila 47 inserida amb èxit amb la clau: United-States_Machine-op-inspct_1699998416594
# Fila 48 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998416695
# Fila 49 inserida amb èxit amb la clau: United-States_Craft-repair_1699998416795
# Fila 50 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998416895
# Fila 51 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998416996
# Fila 52 inserida amb èxit amb la clau: ?_Other-service_1699998417096
# Fila 53 inserida amb èxit amb la clau: Honduras_Prof-specialty_1699998417196
# Fila 54 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998417297
# Fila 55 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998417397
# Fila 56 inserida amb èxit amb la clau: United-States_Tech-support_1699998417497
# Fila 57 inserida amb èxit amb la clau: Mexico_Machine-op-inspct_1699998417598
# Fila 58 inserida amb èxit amb la clau: Puerto-Rico_Other-service_1699998417698
# Fila 59 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998417799
# Fila 60 inserida amb èxit amb la clau: United-States_Machine-op-inspct_1699998417899
# Fila 61 inserida amb èxit amb la clau: United-States_Sales_1699998418000
# Fila 62 inserida amb èxit amb la clau: ?_?_1699998418100
# Fila 63 inserida amb èxit amb la clau: United-States_Transport-moving_1699998418201
# Fila 64 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998418301
# Fila 65 inserida amb èxit amb la clau: United-States_Tech-support_1699998418401
# Fila 66 inserida amb èxit amb la clau: United-States_Craft-repair_1699998418502
# Fila 67 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998418602
# Fila 68 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998418703
# Fila 69 inserida amb èxit amb la clau: United-States_Exec-managerial_1699998418803
# Fila 70 inserida amb èxit amb la clau: United-States_?_1699998418904
# Fila 71 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998419005
# Fila 72 inserida amb èxit amb la clau: United-States_Sales_1699998419105
# Fila 73 inserida amb èxit amb la clau: United-States_Sales_1699998419206
# Fila 74 inserida amb èxit amb la clau: United-States_Machine-op-inspct_1699998419306
# Fila 75 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998419406
# Fila 76 inserida amb èxit amb la clau: Mexico_Other-service_1699998419507
# Fila 77 inserida amb èxit amb la clau: United-States_Adm-clerical_1699998419607
# Fila 78 inserida amb èxit amb la clau: United-States_?_1699998419708
# Fila 79 inserida amb èxit amb la clau: United-States_Other-service_1699998419808
# Fila 80 inserida amb èxit amb la clau: United-States_Farming-fishing_1699998419908
# Fila 81 inserida amb èxit amb la clau: United-States_Sales_1699998420009
# Fila 82 inserida amb èxit amb la clau: Cuba_Other-service_1699998420109
# Fila 83 inserida amb èxit amb la clau: United-States_Other-service_1699998420210
# Fila 84 inserida amb èxit amb la clau: United-States_Sales_1699998420310
# Fila 85 inserida amb èxit amb la clau: United-States_Craft-repair_1699998420410
# Fila 86 inserida amb èxit amb la clau: United-States_Sales_1699998420511
# Fila 87 inserida amb èxit amb la clau: United-States_Protective-serv_1699998420611
# Fila 88 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998420711
# Fila 89 inserida amb èxit amb la clau: United-States_Sales_1699998420812
# Fila 90 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998420912
# Fila 91 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998421012
# Fila 92 inserida amb èxit amb la clau: United-States_Craft-repair_1699998421113
# Fila 93 inserida amb èxit amb la clau: United-States_Machine-op-inspct_1699998421213
# Fila 94 inserida amb èxit amb la clau: ?_Sales_1699998421313
# Fila 95 inserida amb èxit amb la clau: United-States_Protective-serv_1699998421414
# Fila 96 inserida amb èxit amb la clau: United-States_Handlers-cleaners_1699998421514
# Fila 97 inserida amb èxit amb la clau: United-States_Prof-specialty_1699998421615
# Fila 98 inserida amb èxit amb la clau: United-States_Sales_1699998421715
# Fila 99 inserida amb èxit amb la clau: England_Exec-managerial_1699998421815
# Fila 100 inserida amb èxit amb la clau: United-States_Other-service_1699998421916

# %% [markdown]
# ## 2.2 Range queries
#
# Provide below the code required to efficiently implement $Q_2$

# %%
kxn.open()

# Defineix l'interval d'escaneig per a la Q2
start_key = 'United-States_Tech-support_'
end_key = 'United-States_Tech-support_\xff'  # '\xff' s'utilitza com a final de l'interval per cobrir totes les possibles marques de temps

# Escaneja la taula dins de l'interval especificat
scanner = census_table_q2.scan(row_start=start_key, row_stop=end_key)

# Imprimeix els resultats
for key, data in scanner:
        print(f"Key: {key.decode('UTF-8')}, Data: {data}")

kxn.close()
# Out:
# Key: United-States_Tech-support_1699998414386, Data: {b'data:age': b'59', b'data:fnlwgt': b'109015', b'data:workclass': b'Private'}
# Key: United-States_Tech-support_1699998414486, Data: {b'data:age': b'56', b'data:fnlwgt': b'216851', b'data:workclass': b'Local-gov'}
# Key: United-States_Tech-support_1699998416193, Data: {b'data:age': b'24', b'data:fnlwgt': b'172987', b'data:workclass': b'Private'}
# Key: United-States_Tech-support_1699998417497, Data: {b'data:age': b'43', b'data:fnlwgt': b'237993', b'data:workclass': b'Private'}
# Key: United-States_Tech-support_1699998418401, Data: {b'data:age': b'29', b'data:fnlwgt': b'105598', b'data:workclass': b'Private'}
